# %% [markdown]
# # qfin-agent Demo\nRun the end-to-end multi-agent workflow for a ticker symbol.

# %%
# %pip install -q uv\n!uv sync

# %%
import asyncio\nfrom qfin_agent.cli import run_workflow

# %%
result = asyncio.run(run_workflow("AAPL"))\nresult
